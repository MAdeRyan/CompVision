# %%
#Deteksi wajah pada gambar
import cv2
from matplotlib import pyplot as plt

gambar = ["fotorame", "rame1", "rame2", "rame3", "rame4", "rame5", "rame6", "rame7", "rame8", "rame9"]
jumlah_wajah = [15, 6, 8, 10, 4, 5, 4, 4, 11, 6]

for image, wajah in zip(gambar, jumlah_wajah):
  #download folder cascade di https://drive.google.com/file/d/1AcMPiaExIdzCmBc2E24exnPtwIB3_ir6/view?usp=sharing
  # face_cascade = cv2.CascadeClassifier('./cascades/haarcascade_frontalface_default.xml')
  #atau
  face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

  #download gambar di https://drive.google.com/file/d/1UceTLyCk38JRqOqq7mJZazi9ZdEQVu1U/view?usp=sharing
  img = cv2.imread('gambar/'+image+".jpg")
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.08, 5)

  jumlahW = wajah

  wajah_terdeteksi = 0
  for (x, y, w, h) in faces:
      img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
      wajah_terdeteksi+=1
      
  # cv2.namedWindow('Woodcutters Detected!')
#   cv2.imshow("image",img)
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)),plt.show()
  probabilitas = wajah_terdeteksi/jumlahW
  print("probabilitas =",wajah_terdeteksi,"/",jumlahW, "=", probabilitas)

  cv2.imwrite('gambar/'+image+"-detected.jpg", img)
  cv2.waitKey(0)
  cv2.destroyAllWindows()
# Out:
# probabilitas = 6 / 15 = 0.4
# probabilitas = 4 / 6 = 0.6666666666666666
# probabilitas = 10 / 8 = 1.25
# probabilitas = 12 / 10 = 1.2
# probabilitas = 1 / 4 = 0.25
# probabilitas = 3 / 5 = 0.6
# probabilitas = 4 / 4 = 1.0
# probabilitas = 3 / 4 = 0.75
# probabilitas = 7 / 11 = 0.6363636363636364
# probabilitas = 2 / 6 = 0.3333333333333333
